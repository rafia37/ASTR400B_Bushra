# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import ascii
# %matplotlib notebook

# %%
m31 = ascii.read('Orbit_M31.txt')
mw = ascii.read('Orbit_MW.txt')

# %%
def magnitude(x, y, z = 0):
    return np.sqrt(x**2 + y**2 + z**2)

# %%
sep = magnitude(mw['x']-m31['x'], mw['y']-m31['y'], mw['z']-m31['z'])
plt.plot(m31['t'], sep)
# Out:
# <img src="data:image/png;base64,..." width="639.85">
